# %% [markdown]
# <a href="https://colab.research.google.com/github/Seungkyu-Han/colab_ml/blob/main/human_activity_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('test.csv')

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

label = df['Activity']
data = df.drop('Activity', axis=1)

encoder = LabelEncoder()

label_encoded = encoder.fit_transform(label)

X_train, X_test, y_train, y_test = train_test_split(
    data, label_encoded, test_size=0.2, random_state=11
)

# %%
dt_clf = DecisionTreeClassifier(random_state=156)

dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=156)

# %%
pred = dt_clf.predict(X_test)
accuracy = accuracy_score(y_test, pred)

# %%
print(accuracy)
# Out:
# 0.9474576271186441

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth': [i * 2 for i in range(3, 15)],
    'min_samples_split': [16]
}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy', cv=5, verbose=1)
grid_cv.fit(X_train, y_train)
print('GridSearchCV 최고 평균 정확도 수치: {0: .4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터: ', grid_cv.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV 최고 평균 정확도 수치:  0.9389
# GridSearchCV 최적 하이퍼 파라미터:  {'max_depth': 8, 'min_samples_split': 16}

# %%
cv_results_df = pd.DataFrame(grid_cv.cv_results_)

cv_results_df[['param_max_depth', 'mean_test_score']]
# Out:
#     param_max_depth  mean_test_score
# 0                 6         0.925744
# 1                 8         0.938907
# 2                10         0.934662
# 3                12         0.931269
# 4                14         0.932117
# 5                16         0.930846
# 6                18         0.930846
# 7                20         0.930846
# 8                22         0.930846
# 9                24         0.930846
# 10               26         0.930846
# 11               28         0.930846

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'max_depth': [i * 2 for i in range(3, 15)],
    'min_samples_split': [16, 24]
}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy', cv=5, verbose=1)
grid_cv.fit(X_train, y_train)
print('GridSearchCV 최고 평균 정확도 수치: {0: .4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터: ', grid_cv.best_params_)

cv_results_df = pd.DataFrame(grid_cv.cv_results_)

cv_results_df[['param_max_depth', 'mean_test_score']]
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV 최고 평균 정확도 수치:  0.9389
# GridSearchCV 최적 하이퍼 파라미터:  {'max_depth': 8, 'min_samples_split': 16}
#     param_max_depth  mean_test_score
# 0                 6         0.925744
# 1                 6         0.924473
# 2                 8         0.938907
# 3                 8         0.935509
# 4                10         0.934662
# 5                10         0.932114
# 6                12         0.931269
# 7                12         0.933813
# 8                14         0.932117
# 9                14         0.931270
# 10               16         0.930846
# 11               16         0.931270
# 12               18         0.930846
# 13               18         0.931270
# 14               20         0.930846
# 15               20         0.931270
# 16               22         0.930846
# 17               22         0.931270
# 18               24         0.930846
# 19               24         0.931270
# ...

# %%
best_df_clf = grid_cv.best_estimator_

pred1 = best_df_clf.predict(X_test)

accuracy1 = accuracy_score(y_test, pred1)

print(accuracy1)
# Out:
# 0.940677966101695
